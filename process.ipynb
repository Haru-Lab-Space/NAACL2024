# %%
from processDataset import ProcessDataset

# %%
processDataset = ProcessDataset()
processDataset("train")
# Out:
# ...
# Convert process dataset to training dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# text: Will you pick one , just pick one ! Here , how about that one ?
# real_text: Will you pick one , just pick one
# process_text: Will you pick one
# text: Will you pick one , just pick one ! Here , how about that one ?
# real_text: Will you pick one , just pick one
# process_text: Will you pick one , just pick one !
# text: Will you pick one , just pick one ! Here , how about that one ?
# real_text: Will you pick one , just pick one
# process_text: Here , how about that one
# text: That is patio furniture !
# real_text: Will you pick one , just pick one
# process_text: That is patio furniture !
# text: That is patio furniture !
# real_text: Will you pick one , just pick one
# process_text: That is patio furniture
# text: So what , like people are gonna come in and think , " Uh ... oh , I am outside again ? "
# real_text: Will you pick one , just pick one
# ...
