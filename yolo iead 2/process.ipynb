# %%
from processDataset import ProcessDataset

# %%
processDataset = ProcessDataset()
processDataset("train")
# Out:
# ...
# Convert process dataset to training dataset:   9%|▉         | 121/1374 [00:00<00:02, 501.29it/s]
# conver: 11     1    36
# conver: 11     2    42
# conver: 11     3    44
# conver: 11     4    44
# conver: 11     5    44
# conver: 12     7    44
# conver: 12     8    43
# conver: 12     9    40
# conver: 13     4    38
# conver: 13     5    44
# conver: 13     6    48
# conver: 13     7    51
# conver: 13     8    50
# conver: 13     9    53
# conver: 13     10    57
# conver: 13     11    63
# conver: 13     12    64
# conver: 13     13    34
# conver: 14     16    37
# conver: 14     17    40
# conver: 14     18    40
# conver: 14     19    40
# conver: 14     20    39
# conver: 14     21    43
# conver: 14     22    42
# conver: 14     23    38
# conver: 15     7    35
# conver: 15     8    34
# conver: 15     9    33
# conver: 25     11    34
# conver: 25     12    36
# conver: 25     13    38
# conver: 25     14    38
# conver: 25     15    39
# conver: 30     7    45
# ...
